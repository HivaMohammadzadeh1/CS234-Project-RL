# %% [markdown]
# Inference on A100 GPUs (ideally High RAM) on Google Colab, in the 2025-10 runtime environment.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install "transformers==4.57.3" "diffusers @ git+https://github.com/huggingface/diffusers.git"
# !pip install -r "/content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt"
# Out:
# Collecting diffusers@ git+https://github.com/huggingface/diffusers.git
#   Cloning https://github.com/huggingface/diffusers.git to /tmp/pip-install-67kvevhs/diffusers_04448ddd2a7f422883c5e37be1e39754
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers.git /tmp/pip-install-67kvevhs/diffusers_04448ddd2a7f422883c5e37be1e39754
#   Resolved https://github.com/huggingface/diffusers.git to commit ed31974c3e7c7459db066687c7e98a29f0b7769f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers==4.57.3 in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3) (3.25.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3) (4.67.3)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers@ git+https://github.com/huggingface/diffusers.git) (8.7.1)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers@ git+https://github.com/huggingface/diffusers.git) (0.28.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers@ git+https://github.com/huggingface/diffusers.git) (11.3.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers@ git+https://github.com/huggingface/diffusers.git) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers@ git+https://github.com/huggingface/diffusers.git) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers@ git+https://github.com/huggingface/diffusers.git) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers@ git+https://github.com/huggingface/diffusers.git) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers@ git+https://github.com/huggingface/diffusers.git) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.3) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.3) (1.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.3) (4.15.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers@ git+https://github.com/huggingface/diffusers.git) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.3) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.3) (2.5.0)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 2)) (0.25.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 3)) (2.10.0+cu128)
# Requirement already satisfied: opencv-python>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 4)) (4.11.0.86)
# Requirement already satisfied: tokenizers>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 5)) (0.22.2)
# Requirement already satisfied: accelerate>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 6)) (1.13.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 7)) (4.67.3)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 9)) (1.13)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 10)) (6.3.1)
# Requirement already satisfied: dashscope in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (1.25.14)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 12)) (0.6.0)
# Requirement already satisfied: numpy<2,>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 13)) (1.26.4)
# Requirement already satisfied: imageio[ffmpeg] in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 8)) (2.37.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (1.4.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.19.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 2)) (11.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.20.3->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 5)) (0.36.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.1.1->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 6)) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.1.1->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 6)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.1.1->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 6)) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.1.1->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 10)) (0.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (3.13.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (2.32.4)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.12/dist-packages (from dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (1.9.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (43.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (2026.2.25)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.20.3->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 5)) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (1.23.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 1)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn-plz-work.txt (line 11)) (3.0)

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
# !git clone https://github.com/Wan-Video/Wan2.2.git
# %cd Wan2.2
# !pip install -r "/content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt"
# Out:
# Cloning into 'Wan2.2'...
# remote: Enumerating objects: 259, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 259 (delta 73), reused 64 (delta 64), pack-reused 121 (from 1)
# Receiving objects: 100% (259/259), 8.14 MiB | 11.90 MiB/s, done.
# Resolving deltas: 100% (110/110), done.
# /content/Wan2.2
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 2)) (0.25.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 3)) (2.10.0+cu128)
# Requirement already satisfied: opencv-python>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 4)) (4.11.0.86)
# Requirement already satisfied: diffusers>=0.31.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (0.38.0.dev0)
# Requirement already satisfied: tokenizers>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 6)) (0.22.2)
# Requirement already satisfied: accelerate>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 7)) (1.13.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 8)) (4.67.3)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 10)) (1.13)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 11)) (6.3.1)
# Requirement already satisfied: dashscope in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (1.25.14)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 13)) (0.6.0)
# Requirement already satisfied: numpy<2,>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 14)) (1.26.4)
# Requirement already satisfied: imageio[ffmpeg] in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 9)) (2.37.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (1.4.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.19.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 2)) (11.3.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (8.7.1)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (0.36.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (2.32.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (0.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.1.1->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 7)) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.1.1->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 7)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.1.1->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 7)) (6.0.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 11)) (0.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (3.13.3)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.12/dist-packages (from dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (1.9.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (43.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (2026.2.25)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (1.23.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (2.0.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 1)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers>=0.31.0->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 5)) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->dashscope->-r /content/drive/MyDrive/CS234_Project/utils/wan-requirements-no-flash-attn.txt (line 12)) (3.0)

# %%
# !pip install "huggingface_hub[cli]"
# !huggingface-cli download Wan-AI/Wan2.2-TI2V-5B --local-dir ./Wan2.2-TI2V-5B
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: huggingface_hub[cli] in /usr/local/lib/python3.12/dist-packages (0.36.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (1.4.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (4.15.0)
# Collecting InquirerPy==0.3.4 (from huggingface_hub[cli])
#   Downloading InquirerPy-0.3.4-py3-none-any.whl.metadata (8.1 kB)
# Collecting pfzy<0.4.0,>=0.3.1 (from InquirerPy==0.3.4->huggingface_hub[cli])
#   Downloading pfzy-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (3.0.52)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[cli]) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[cli]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[cli]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[cli]) (2026.2.25)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface_hub[cli]) (0.6.0)
# Downloading InquirerPy-0.3.4-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 7.8 MB/s eta 0:00:00
# Downloading pfzy-0.3.4-py3-none-any.whl (8.5 kB)
# Installing collected packages: pfzy, InquirerPy
# Successfully installed InquirerPy-0.3.4 pfzy-0.3.4
# ⚠️  Warning: 'huggingface-cli download' is deprecated. Use 'hf download' instead.
# Fetching 23 files:   0% 0/23 [00:00<?, ?it/s]Downloading 'assets/logo.png' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/assets/gvouIpVGo_vjLxWDOGAmKk_SZvY=.0c55854cbd9692975f217714ffd83fd4b37f5dca.incomplete'
# Downloading '.mv' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/TMvir_q0dnrJoBi-VP-reJNJVIY=.acac14f612675621cd9d2529ad4a590bfd9d0546.incomplete'
#
# logo.png: 100% 56.3k/56.3k [00:00<00:00, 117MB/s]
# Downloading 'assets/comp_effic.png' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/assets/X4-4NQEdffK1bUQbDx0NJ4IbcNo=.75ee012dcfb08365bec67a3ec7afc126fc2817f79b9f80e38711792d4770e32b.incomplete'
# Download complete. Moving file to Wan2.2-TI2V-5B/assets/logo.png
#
# .mv: 100% 36.0/36.0 [00:00<00:00, 271kB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/.mv
# Downloading 'assets/moe_2.png' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/assets/nRet4S88FozLSSwTJNookKkPe2U=.4ea471ccb64349bd08bc9a78f336ae000e9ca3b40da9a652b8028b214a8c6093.incomplete'
# Downloading '.gitattributes' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.4b227fbecf653a7faf8b46492810c4a2174c7431.incomplete'
# Downloading 'README.md' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.40523d8b626810c1ff5293746d181fb99aca6a7a.incomplete'
#
# .gitattributes: 1.87kB [00:00, 12.8MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/.gitattributes
#
# README.md: 15.9kB [00:00, 49.1MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/README.md
# Fetching 23 files:   4% 1/23 [00:00<00:07,  3.11it/s]Downloading 'Wan2.2_VAE.pth' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/CHzdR2H1q5_tJrjQMk3clUgGTXg=.20eb789667fa5e60e7516bf509512f6cb61f01b0aa0695eadaea930c13892b36.incomplete'
# Downloading '.msc' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/yGuuhN3jcMp8wjph_sAk9JRj2EM=.b9cd87580ba33d16a89a8cd9db0cbc67efe4fc79.incomplete'
#
# .msc: 100% 507/507 [00:00<00:00, 6.04MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/.msc
#
# assets/comp_effic.png:   0% 0.00/202k [00:00<?, ?B/s]Downloading 'assets/moe_arch.png' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/assets/PxF_a-FLJ44WN1MONdliwvhjiOg=.7822af1e65215ee2a9449c9b7616afd713f67a01.incomplete'
#
#
# assets/moe_2.png:   0% 0.00/528k [00:00<?, ?B/s]Downloading 'assets/performance.png' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/assets/82SfNOaJIZo5zsyAX2vafak-9FA=.97ef99c13c8ae717a8a11c8d8ec927b69077c647cc6689755d08fc38e7fbb830.incomplete'
#
#
#
# moe_arch.png: 100% 74.9k/74.9k [00:00<00:00, 215MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/assets/moe_arch.png
# Downloading 'assets/vae.png' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/assets/wxqqE9bvovHNN6I2pgKdH8nIAKo=.4aaea5e187f1c5908e15ade5bef24c9fb59882986bc3d2ad75f7fe820f3d772f.incomplete'
# Downloading 'config.json' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.abb356dedbca416450700e180a6622626d789601.incomplete'
#
#
#
# config.json: 100% 251/251 [00:00<00:00, 2.81MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/config.json
#
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:00<?, ?B/s]Downloading 'configuration.json' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/pOL2LEBeNWU9Y3bTUNO_khibHs8=.d64db5cb6ceecfb2c7f0929427dc5f48bc4b7f37.incomplete'
#
#
#
#
# configuration.json: 100% 43.0/43.0 [00:00<00:00, 508kB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/configuration.json
#
#
# assets/moe_2.png:   0% 0.00/528k [00:00<?, ?B/s]
# assets/comp_effic.png:   0% 0.00/202k [00:00<?, ?B/s]
#
#
#
# assets/performance.png:   0% 0.00/307k [00:00<?, ?B/s]
#
#
#
#
# assets/vae.png:   0% 0.00/165k [00:00<?, ?B/s]Downloading 'diffusion_pytorch_model-00001-of-00003.safetensors' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/5n3ByLHcDVGl-4O5UeVdJRvodxk=.720b06c4ade5e87c1246bba8ac95b664c638749cd9b102cf84d823bb44c026a1.incomplete'
#
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:00<?, ?B/s]Downloading 'diffusion_pytorch_model-00002-of-00003.safetensors' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/xIb00LLWe-iHth2j35r6TGIYKx8=.09ec5ef720d8396f6cfa51fbdcbdb2327e37722afd6e89fd38f1e7e5e782c283.incomplete'
# Downloading 'diffusion_pytorch_model-00003-of-00003.safetensors' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/GwHdKznehhuKvEEAo-cIQ3kH9qA=.6306f7894c345de9093ad588771c2abfaeb668a81f7a6d9a918bd26ba3568e49.incomplete'
#
# assets/comp_effic.png:   0% 0.00/202k [00:00<?, ?B/s]
#
# assets/moe_2.png:   0% 0.00/528k [00:00<?, ?B/s]
#
#
#
# assets/performance.png:   0% 0.00/307k [00:00<?, ?B/s]
#
#
#
#
# assets/vae.png:   0% 0.00/165k [00:00<?, ?B/s]
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:00<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   0% 0.00/9.83G [00:00<?, ?B/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model-00003-of-00003.s(…):   0% 0.00/179M [00:00<?, ?B/s]
#
# assets/moe_2.png:   0% 0.00/528k [00:00<?, ?B/s]
# assets/comp_effic.png:   0% 0.00/202k [00:00<?, ?B/s]
#
#
#
# assets/performance.png:   0% 0.00/307k [00:00<?, ?B/s]
#
#
#
#
# assets/vae.png:   0% 0.00/165k [00:00<?, ?B/s]
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:00<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   0% 0.00/9.83G [00:00<?, ?B/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model-00003-of-00003.s(…):   0% 0.00/179M [00:00<?, ?B/s]
# assets/comp_effic.png:   0% 0.00/202k [00:00<?, ?B/s]
#
# assets/moe_2.png:   0% 0.00/528k [00:00<?, ?B/s]
#
#
#
# assets/performance.png:   0% 0.00/307k [00:00<?, ?B/s]
#
#
#
#
# assets/vae.png:   0% 0.00/165k [00:00<?, ?B/s]
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:00<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   0% 0.00/9.83G [00:00<?, ?B/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model-00003-of-00003.s(…):   0% 0.00/179M [00:00<?, ?B/s]
#
# assets/moe_2.png:   0% 0.00/528k [00:01<?, ?B/s]
# assets/comp_effic.png:   0% 0.00/202k [00:01<?, ?B/s]
#
#
#
# assets/performance.png:   0% 0.00/307k [00:00<?, ?B/s]
#
#
#
#
# assets/vae.png:   0% 0.00/165k [00:00<?, ?B/s]
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:01<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   0% 0.00/9.83G [00:00<?, ?B/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model-00003-of-00003.s(…):   0% 0.00/179M [00:00<?, ?B/s]
# assets/comp_effic.png: 100% 202k/202k [00:01<00:00, 1.01MB/s]
#
# assets/comp_effic.png: 100% 202k/202k [00:01<00:00, 165kB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/assets/comp_effic.png
#
#
#
#
# assets/performance.png:   0% 0.00/307k [00:01<?, ?B/s]
#
#
#
#
# assets/vae.png: 100% 165k/165k [00:01<00:00, 163kB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/assets/vae.png
#
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:01<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   0% 0.00/9.83G [00:00<?, ?B/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model-00003-of-00003.s(…):   0% 0.00/179M [00:00<?, ?B/s]
#
# assets/moe_2.png: 100% 528k/528k [00:01<00:00, 374kB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/assets/moe_2.png
#
#
#
#
# assets/performance.png: 100% 307k/307k [00:01<00:00, 252kB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/assets/performance.png
# Downloading 'diffusion_pytorch_model.safetensors.index.json' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/VpHHFEQcyqWBKjkjOBMoMr6uTZU=.2a1d8b9ee7cd1456f79f944ae15c87724d49110e.incomplete'
#
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:01<?, ?B/s]
# (…)ion_pytorch_model.safetensors.index.json: 72.9kB [00:00, 130MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/diffusion_pytorch_model.safetensors.index.json
#
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   0% 0.00/9.83G [00:01<?, ?B/s]Downloading 'examples/i2v_input.JPG' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/examples/GqO1vCXUoNdTZc6wjxo1L7sjRdI=.077e3d965090c9028c69c00931675f42e1acc815c6eb450ab291b3b72d211a8e.incomplete'
#
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:01<?, ?B/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model-00003-of-00003.s(…):   0% 0.00/179M [00:01<?, ?B/s]Downloading 'google/umt5-xxl/special_tokens_map.json' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/google/umt5-xxl/ahkChHUJFxEmOdq5GDFEmerRzCY=.14855e7052ffbb595057dfd791d293c1c940db2c.incomplete'
#
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:01<?, ?B/s]
# special_tokens_map.json: 6.62kB [00:00, 13.1MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/google/umt5-xxl/special_tokens_map.json
#
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   0% 0.00/9.83G [00:01<?, ?B/s]Downloading 'google/umt5-xxl/spiece.model' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/google/umt5-xxl/vj8E1loknrCNPSP8nWJC234Bff4=.e3909a67b780650b35cf529ac782ad2b6b26e6d1f849d3fbb6a872905f452458.incomplete'
#
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:01<?, ?B/s]Downloading 'google/umt5-xxl/tokenizer.json' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/google/umt5-xxl/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.6e197b4d3dbd71da14b4eb255f4fa91c9c1f2068b20a2de2472967ca3d22602b.incomplete'
#
# examples/i2v_input.JPG:   0% 0.00/251k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model-00003-of-00003.s(…):   0% 0.00/179M [00:01<?, ?B/s]
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:01<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   0% 0.00/9.83G [00:01<?, ?B/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:01<?, ?B/s]Downloading 'google/umt5-xxl/tokenizer_config.json' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/google/umt5-xxl/vzaExXFZNBay89bvlQv-ZcI6BTg=.4e1cc1cd85599ce0b47fd0a746af188fe4043ff2.incomplete'
#
#
# tokenizer_config.json: 61.7kB [00:00, 114MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/google/umt5-xxl/tokenizer_config.json
#
#
# google/umt5-xxl/tokenizer.json:   0% 0.00/16.8M [00:00<?, ?B/s]
# examples/i2v_input.JPG:   0% 0.00/251k [00:00<?, ?B/s]
#
#
#
# google/umt5-xxl/spiece.model:   0% 0.00/4.55M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model-00003-of-00003.s(…):   0% 0.00/179M [00:01<?, ?B/s]
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:02<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   0% 0.00/9.83G [00:01<?, ?B/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:01<?, ?B/s]
# examples/i2v_input.JPG: 100% 251k/251k [00:00<00:00, 600kB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/examples/i2v_input.JPG
#
#
# google/umt5-xxl/tokenizer.json:   0% 0.00/16.8M [00:00<?, ?B/s]
#
#
#
# google/umt5-xxl/spiece.model:   0% 0.00/4.55M [00:00<?, ?B/s]Downloading 'models_t5_umt5-xxl-enc-bf16.pth' to 'Wan2.2-TI2V-5B/.cache/huggingface/download/7xjTyx9p9-CteGiI3VEINu_Ohx0=.7cace0da2b446bbbbc57d031ab6cf163a3d59b366da94e5afe36745b746fd81d.incomplete'
#
#
#
#
#
#
#
#
# diffusion_pytorch_model-00003-of-00003.s(…):   0% 0.00/179M [00:01<?, ?B/s]
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:02<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   0% 0.00/9.83G [00:01<?, ?B/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:01<?, ?B/s]
#
# google/umt5-xxl/tokenizer.json:   0% 0.00/16.8M [00:00<?, ?B/s]
#
#
#
# google/umt5-xxl/spiece.model: 100% 4.55M/4.55M [00:00<00:00, 10.9MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/google/umt5-xxl/spiece.model
#
#
#
#
#
#
#
#
# diffusion_pytorch_model-00003-of-00003.s(…):   0% 0.00/179M [00:01<?, ?B/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:00<?, ?B/s]
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:02<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   0% 0.00/9.83G [00:02<?, ?B/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:02<?, ?B/s]
#
# google/umt5-xxl/tokenizer.json: 100% 16.8M/16.8M [00:00<00:00, 27.5MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/google/umt5-xxl/tokenizer.json
#
#
#
#
#
#
#
#
# diffusion_pytorch_model-00003-of-00003.s(…):  38% 67.1M/179M [00:02<00:00, 335MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:00<?, ?B/s]
#
#
# Wan2.2_VAE.pth:   0% 0.00/2.82G [00:02<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   1% 67.1M/9.83G [00:02<00:29, 336MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:02<?, ?B/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:00<?, ?B/s]
#
#
# Wan2.2_VAE.pth:   7% 201M/2.82G [00:02<00:02, 1.01GB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   0% 0.00/10.0G [00:02<?, ?B/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:00<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   1% 134M/9.83G [00:02<00:45, 211MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   1% 134M/10.0G [00:02<00:15, 651MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model-00003-of-00003.s(…): 100% 179M/179M [00:02<00:00, 68.3MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/diffusion_pytorch_model-00003-of-00003.safetensors
#
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:00<?, ?B/s]
#
#
# Wan2.2_VAE.pth:  12% 335M/2.82G [00:03<00:04, 509MB/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   2% 201M/9.83G [00:02<00:37, 254MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   2% 201M/10.0G [00:02<00:20, 476MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:01<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   3% 268M/9.83G [00:03<00:34, 281MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:01<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   3% 335M/9.83G [00:03<00:31, 298MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   3% 256M/10.0G [00:03<00:37, 263MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:01<?, ?B/s]
#
#
# Wan2.2_VAE.pth:  19% 537M/2.82G [00:03<00:05, 401MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   3% 335M/10.0G [00:03<00:31, 304MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:01<?, ?B/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:01<?, ?B/s]
#
#
# Wan2.2_VAE.pth:  21% 604M/2.82G [00:04<00:07, 316MB/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   4% 402M/9.83G [00:03<00:49, 190MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:02<?, ?B/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   5% 469M/9.83G [00:04<00:42, 219MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:02<?, ?B/s]
#
#
# Wan2.2_VAE.pth:  24% 671M/2.82G [00:04<00:08, 265MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   5% 470M/10.0G [00:04<00:43, 217MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:02<?, ?B/s]
# models_t5_umt5-xxl-enc-bf16.pth:   0% 0.00/11.4G [00:02<?, ?B/s]
# models_t5_umt5-xxl-enc-bf16.pth:   2% 201M/11.4G [00:02<00:11, 1.00GB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   5% 537M/10.0G [00:04<00:54, 173MB/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   6% 603M/9.83G [00:05<01:01, 150MB/s]
#
#
# Wan2.2_VAE.pth:  29% 805M/2.82G [00:05<00:11, 174MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:   4% 469M/11.4G [00:05<01:02, 175MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):   8% 805M/10.0G [00:07<01:06, 139MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:   9% 1.01G/11.4G [00:09<01:15, 136MB/s]
#
#
# Wan2.2_VAE.pth:  57% 1.61G/2.82G [00:14<00:11, 109MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  14% 1.41G/10.0G [00:13<01:23, 103MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  11% 1.21G/11.4G [00:11<01:26, 117MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  17% 1.68G/10.0G [00:14<01:02, 134MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  11% 1.27G/11.4G [00:12<01:33, 108MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  14% 1.54G/11.4G [00:16<01:43, 94.7MB/s]
#
#
# Wan2.2_VAE.pth:  95% 2.68G/2.82G [00:19<00:00, 151MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  21% 2.08G/10.0G [00:18<01:11, 111MB/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):   6% 603M/9.83G [00:18<01:01, 150MB/s]
#
#
# Wan2.2_VAE.pth: 100% 2.82G/2.82G [00:21<00:00, 134MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/Wan2.2_VAE.pth
# Fetching 23 files:  22% 5/23 [00:21<01:22,  4.57s/it]
# models_t5_umt5-xxl-enc-bf16.pth:  16% 1.81G/11.4G [00:19<01:40, 95.1MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  23% 2.35G/10.0G [00:21<01:07, 114MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  21% 2.35G/11.4G [00:22<01:17, 116MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  29% 2.88G/10.0G [00:24<00:56, 127MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  21% 2.41G/11.4G [00:23<01:15, 119MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  30% 2.95G/10.0G [00:25<00:56, 126MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  22% 2.48G/11.4G [00:23<01:14, 118MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  30% 3.02G/10.0G [00:25<00:56, 124MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  25% 2.82G/11.4G [00:26<01:13, 115MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  34% 3.35G/10.0G [00:28<00:54, 122MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  34% 3.42G/10.0G [00:28<00:50, 131MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  35% 3.49G/10.0G [00:29<00:50, 128MB/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):  21% 2.08G/9.83G [00:29<01:59, 65.0MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  26% 2.95G/11.4G [00:27<01:13, 115MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  27% 3.08G/11.4G [00:30<01:28, 93.2MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  36% 3.62G/10.0G [00:32<01:11, 88.5MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  42% 4.23G/10.0G [00:36<00:48, 120MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  32% 3.62G/11.4G [00:34<01:10, 110MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  43% 4.29G/10.0G [00:36<00:44, 127MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  33% 3.76G/11.4G [00:34<00:59, 127MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  34% 3.82G/11.4G [00:35<00:57, 131MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  44% 4.36G/10.0G [00:37<00:50, 111MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  35% 4.02G/11.4G [00:38<01:17, 94.9MB/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):  37% 3.62G/9.83G [00:40<01:06, 93.5MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  37% 4.22G/11.4G [00:38<00:56, 127MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  48% 4.76G/10.0G [00:40<00:44, 118MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  38% 4.29G/11.4G [00:39<00:51, 137MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  48% 4.83G/10.0G [00:41<00:42, 122MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  49% 4.90G/10.0G [00:42<00:44, 115MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  50% 5.03G/10.0G [00:44<00:55, 89.2MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  39% 4.43G/11.4G [00:42<01:26, 79.9MB/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):  48% 4.76G/9.83G [00:48<00:47, 107MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  45% 5.10G/11.4G [00:46<00:52, 119MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  57% 5.70G/10.0G [00:48<00:34, 123MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  45% 5.16G/11.4G [00:47<00:52, 119MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  46% 5.23G/11.4G [00:48<00:57, 106MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  58% 5.83G/10.0G [00:52<00:47, 88.1MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  53% 6.04G/11.4G [00:52<00:33, 160MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  54% 6.10G/11.4G [00:53<00:34, 150MB/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):  58% 5.70G/9.83G [00:55<00:35, 115MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  56% 6.37G/11.4G [00:56<00:43, 116MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  66% 6.57G/10.0G [00:58<00:32, 105MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  59% 6.71G/11.4G [00:58<00:35, 130MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  61% 6.97G/11.4G [01:01<00:37, 118MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  72% 7.24G/10.0G [01:03<00:23, 117MB/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):  70% 6.91G/9.83G [01:03<00:23, 125MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  63% 7.11G/11.4G [01:01<00:32, 132MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  63% 7.18G/11.4G [01:02<00:33, 125MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  64% 7.24G/11.4G [01:04<00:40, 103MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  77% 7.71G/10.0G [01:07<00:19, 117MB/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):  78% 7.65G/9.83G [01:09<00:17, 127MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  70% 7.91G/11.4G [01:09<00:29, 116MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  85% 8.52G/10.0G [01:13<00:11, 125MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  73% 8.31G/11.4G [01:13<00:27, 110MB/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):  88% 8.65G/9.83G [01:17<00:09, 127MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  78% 8.85G/11.4G [01:17<00:21, 116MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…):  94% 9.39G/10.0G [01:20<00:04, 125MB/s]
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…):  95% 9.32G/9.83G [01:23<00:04, 120MB/s]
# models_t5_umt5-xxl-enc-bf16.pth:  82% 9.32G/11.4G [01:21<00:17, 115MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model-00002-of-00003.s(…): 100% 10.0G/10.0G [01:24<00:00, 118MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/diffusion_pytorch_model-00002-of-00003.safetensors
#
#
#
#
#
#
# diffusion_pytorch_model-00001-of-00003.s(…): 100% 9.83G/9.83G [01:26<00:00, 114MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/diffusion_pytorch_model-00001-of-00003.safetensors
# Fetching 23 files:  61% 14/23 [01:27<00:58,  6.55s/it]
# models_t5_umt5-xxl-enc-bf16.pth:  93% 10.6G/11.4G [01:25<00:04, 180MB/s]
# models_t5_umt5-xxl-enc-bf16.pth: 100% 11.4G/11.4G [01:27<00:00, 129MB/s]
# Download complete. Moving file to Wan2.2-TI2V-5B/models_t5_umt5-xxl-enc-bf16.pth
# Fetching 23 files: 100% 23/23 [01:30<00:00,  3.95s/it]
# /content/Wan2.2/Wan2.2-TI2V-5B

# %% [markdown]
# Try to generate video:

# %%
# # Try to generate video

# import torch
# import numpy as np
# from diffusers import WanPipeline, AutoencoderKLWan, WanTransformer3DModel, UniPCMultistepScheduler
# from diffusers.utils import export_to_video, load_image

# dtype = torch.bfloat16
# device = "cuda"

# model_id = "Wan-AI/Wan2.2-TI2V-5B-Diffusers"
# vae = AutoencoderKLWan.from_pretrained(model_id, subfolder="vae", torch_dtype=torch.float32)
# pipe = WanPipeline.from_pretrained(model_id, vae=vae, torch_dtype=dtype)
# pipe.to(device)

# ## comment below

# height = 704
# width = 1280
# num_frames = 81# 121
# num_inference_steps = 20 #40
# guidance_scale = 3.5


# prompt = "A tennis ball falling from 2 meters onto a hard concrete floor and bouncing several times. Static camera, side view."

# output = pipe(
#     prompt=prompt,
#     # negative_prompt=negative_prompt,
#     height=height,
#     width=width,
#     num_frames=num_frames,
#     guidance_scale=guidance_scale,
#     num_inference_steps=num_inference_steps,
# ).frames[0]
# export_to_video(output, "5bit2v_output.mp4", fps=24)

# %% [markdown]
# Try to run reward model:

# %%
# # Try to run reward model


# # for batch in dataloader:
# # batch now contains your pixel_values, input_ids, etc.
# prompt = "Hello world"
# # Forward pass: Feed the tensors directly
# video_a = vl_prompt_batch(videos = ["/content/5bit2v_output (2).mp4"], prompts = [prompt],
#                         sample_fps = 64)
# # video_b = vl_prompt_batch(videos = [os.path.join("wan22-dataset", "videos", v) for v in batch['video_b']], prompts = batch['prompt'],
# #                         sample_fps = 64)
# # print(video_a)
# # exit(0)

# # # model(output_ids = model.generate(**inputs, max_new_tokens=max_new_tokens))
# # print(video_a)
# # del video_a
# # break
# # exit(0)
# reward_a = lora_rm(**video_a)#.logits.squeeze(-1)
# # print(reward_a)
# del video_a
# # reward_b = lora_rm(**video_b)#.logits.squeeze(-1)
# # del video_b
# # print(reward_a)
# # pred_logits = torch.stack([reward_a, reward_b], dim = -1)
# # del reward_a, reward_b
# # target = torch.stack([batch['score_a'], batch['score_b']], dim = -1).to(torch.bfloat16).to(device)
# # # print(pred_logits)
# # # print(target)
# # crossentropy = torch.nn.CrossEntropyLoss()
# # loss = crossentropy(pred_logits, target)
# # # print(loss)
# # del pred_logits, target

# print(reward_a)

# # torch.cuda.empty_cache()

# # gc.collect()
# # # exit(0)
# # break
# Out:
# tensor([-16.], device='cuda:0', dtype=torch.bfloat16,
#        grad_fn=<SqueezeBackward1>)

# %%
# !pip install qwen_vl_utils decord datasets accelerate peft bitsandbytes wandb ninja
# Out:
# Collecting qwen_vl_utils
#   Downloading qwen_vl_utils-0.0.14-py3-none-any.whl.metadata (9.0 kB)
# Collecting decord
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl.metadata (422 bytes)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.18.1)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.25.1)
# Collecting ninja
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting av (from qwen_vl_utils)
#   Downloading av-17.0.0-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from qwen_vl_utils) (26.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from qwen_vl_utils) (11.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from qwen_vl_utils) (2.32.4)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from decord) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.10.0+cu128)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.7.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from peft) (4.57.3)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.9.4)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<7,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.12.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.54.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb) (4.15.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->qwen_vl_utils) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->qwen_vl_utils) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->qwen_vl_utils) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->qwen_vl_utils) (2026.2.25)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->peft) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->peft) (0.22.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Downloading qwen_vl_utils-0.0.14-py3-none-any.whl (8.1 kB)
# Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 41.5 MB/s eta 0:00:00
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 33.2 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 21.0 MB/s eta 0:00:00
# Downloading av-17.0.0-cp311-abi3-manylinux_2_28_x86_64.whl (36.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 48.0 MB/s eta 0:00:00
# Installing collected packages: ninja, decord, av, qwen_vl_utils, bitsandbytes
# Successfully installed av-17.0.0 bitsandbytes-0.49.2 decord-0.6.0 ninja-1.13.0 qwen_vl_utils-0.0.14

# %% [markdown]
# Load video frames and timestamps

# %%
import os
import math
import hashlib
import requests

from IPython.display import Markdown, display
import numpy as np
from PIL import Image
import decord
from decord import VideoReader, cpu


def download_video(url, dest_path):
    response = requests.get(url, stream=True)
    with open(dest_path, 'wb') as f:
        for chunk in response.iter_content(chunk_size=8096):
            f.write(chunk)
    print(f"Video downloaded to {dest_path}")


def get_video_frames(video_path, num_frames=128, cache_dir='.cache'):
    os.makedirs(cache_dir, exist_ok=True)

    video_hash = hashlib.md5(video_path.encode('utf-8')).hexdigest()
    if video_path.startswith('http://') or video_path.startswith('https://'):
        video_file_path = os.path.join(cache_dir, f'{video_hash}.mp4')
        if not os.path.exists(video_file_path):
            download_video(video_path, video_file_path)
    else:
        video_file_path = video_path

    frames_cache_file = os.path.join(cache_dir, f'{video_hash}_{num_frames}_frames.npy')
    timestamps_cache_file = os.path.join(cache_dir, f'{video_hash}_{num_frames}_timestamps.npy')

    if os.path.exists(frames_cache_file) and os.path.exists(timestamps_cache_file):
        frames = np.load(frames_cache_file)
        timestamps = np.load(timestamps_cache_file)
        return video_file_path, frames, timestamps

    vr = VideoReader(video_file_path, ctx=cpu(0))
    total_frames = len(vr)

    indices = np.linspace(0, total_frames - 1, num=num_frames, dtype=int)
    frames = vr.get_batch(indices).asnumpy()
    timestamps = np.array([vr.get_frame_timestamp(idx) for idx in indices])

    np.save(frames_cache_file, frames)
    np.save(timestamps_cache_file, timestamps)

    return video_file_path, frames, timestamps


def create_image_grid(images, num_columns=8):
    pil_images = [Image.fromarray(image) for image in images]
    num_rows = math.ceil(len(images) / num_columns)

    img_width, img_height = pil_images[0].size
    grid_width = num_columns * img_width
    grid_height = num_rows * img_height
    grid_image = Image.new('RGB', (grid_width, grid_height))

    for idx, image in enumerate(pil_images):
        row_idx = idx // num_columns
        col_idx = idx % num_columns
        position = (col_idx * img_width, row_idx * img_height)
        grid_image.paste(image, position)

    return grid_image

# %% [markdown]
# Inference function

# %%
from qwen_vl_utils import process_vision_info
def inference(video, prompt, max_new_tokens=2048, total_pixels=20480 * 32 * 32, min_pixels=64 * 32 * 32, max_frames= 2048, sample_fps = 2):
    """
    Perform multimodal inference on input video and text prompt to generate model response.

    Args:
        video (str or list/tuple): Video input, supports two formats:
            - str: Path or URL to a video file. The function will automatically read and sample frames.
            - list/tuple: Pre-sampled list of video frames (PIL.Image or url).
              In this case, `sample_fps` indicates the frame rate at which these frames were sampled from the original video.
        prompt (str): User text prompt to guide the model's generation.
        max_new_tokens (int, optional): Maximum number of tokens to generate. Default is 2048.
        total_pixels (int, optional): Maximum total pixels for video frame resizing (upper bound). Default is 20480*32*32.
        min_pixels (int, optional): Minimum total pixels for video frame resizing (lower bound). Default is 16*32*32.
        sample_fps (int, optional): ONLY effective when `video` is a list/tuple of frames!
            Specifies the original sampling frame rate (FPS) from which the frame list was extracted.
            Used for temporal alignment or normalization in the model. Default is 2.

    Returns:
        str: Generated text response from the model.

    Notes:
        - When `video` is a string (path/URL), `sample_fps` is ignored and will be overridden by the video reader backend.
        - When `video` is a frame list, `sample_fps` informs the model of the original sampling rate to help understand temporal density.
    """

    messages = [
        {"role": "user", "content": [
                {"video": video,
                "total_pixels": total_pixels,
                "min_pixels": min_pixels,
                "max_frames": max_frames,
                'sample_fps':sample_fps},
                {"type": "text", "text": prompt},
            ]
        },
    ]
    text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    image_inputs, video_inputs, video_kwargs = process_vision_info([messages], return_video_kwargs=True,
                                                                   image_patch_size= 16,
                                                                   return_video_metadata=True)
    if video_inputs is not None:
        video_inputs, video_metadatas = zip(*video_inputs)
        video_inputs, video_metadatas = list(video_inputs), list(video_metadatas)
    else:
        video_metadatas = None
    inputs = processor(text=[text], images=image_inputs, videos=video_inputs, video_metadata=video_metadatas, **video_kwargs, do_resize=False, return_tensors="pt")
    inputs = inputs.to('cuda')

    output_ids = model.generate(**inputs, max_new_tokens=max_new_tokens)
    generated_ids = [output_ids[len(input_ids):] for input_ids, output_ids in zip(inputs.input_ids, output_ids)]
    output_text = processor.batch_decode(generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True)
    return output_text[0]

# %% [markdown]
# # Video Model Setup

# %%
from datasets import load_dataset
ds = load_dataset("hivamoh/wan22-physics-videos", data_files="metadata.csv")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# metadata.csv: 0.00B [00:00, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
import torch
test_indices = torch.Tensor([0,1,8,15,21,25,27,28,45,48,50,52]) * 8

# %%
test_prompts = ds['train']['prompt'][test_indices]

# %%
class VideoPreferenceDataset(torch.utils.data.Dataset):
    def __init__(self, data_list):
        self.data = data_list  # List of {"prompt": "...", "chosen": "v1.mp4", "rejected": "v2.mp4"}

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Simply return the raw paths
        return self.data[idx]

class PromptsDataset(torch.utils.data.Dataset):
    def __init__(self, data_list):
        self.data = data_list  # List of {"prompt": "...", "chosen": "v1.mp4", "rejected": "v2.mp4"}

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Simply return the raw paths
        return self.data[idx]

# %%
test_prompts = PromptsDataset(test_prompts)

# %%
dataloader = torch.utils.data.DataLoader(test_prompts[10:], batch_size=1, shuffle=False)

# %% [markdown]
# Try if we can generate video + prompt

# %%
import torch
import numpy as np
import gc
import os
from diffusers import WanPipeline, AutoencoderKLWan
from diffusers.utils import export_to_video

dtype = torch.bfloat16
device = "cuda"
model_id = "Wan-AI/Wan2.2-TI2V-5B-Diffusers"

# ── Model loading ─────────────────────────────────────────────────────────────
vae = AutoencoderKLWan.from_pretrained(model_id, subfolder="vae", torch_dtype=torch.float32)
pipe = WanPipeline.from_pretrained(model_id, vae=vae, torch_dtype=dtype)
# pipe.to(device)
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# config.json: 0.00B [00:00, ?B/s]
# vae/diffusion_pytorch_model.safetensors:   0%|          | 0.00/2.82G [00:00<?, ?B/s]
# The config attributes {'clip_output': False} were passed to AutoencoderKLWan, but are not expected and will be ignored. Please verify your config.json configuration file.
# model_index.json:   0%|          | 0.00/499 [00:00<?, ?B/s]
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/820 [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# text_encoder/model-00001-of-00003.safete(…):   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# text_encoder/model-00002-of-00003.safete(…):   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# tokenizer/spiece.model:   0%|          | 0.00/4.55M [00:00<?, ?B/s]
# text_encoder/model-00003-of-00003.safete(…):   0%|          | 0.00/1.44G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/495 [00:00<?, ?B/s]
# tokenizer/tokenizer.json:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# transformer/diffusion_pytorch_model-0000(…):   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# transformer/diffusion_pytorch_model-0000(…):   0%|          | 0.00/4.85G [00:00<?, ?B/s]
# transformer/diffusion_pytorch_model-0000(…):   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# transformer/diffusion_pytorch_model-0000(…):   0%|          | 0.00/4.85G [00:00<?, ?B/s]
# transformer/diffusion_pytorch_model-0000(…):   0%|          | 0.00/355M [00:00<?, ?B/s]
# (…)ion_pytorch_model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
pipe.text_encoder.to(device)
pipe.transformer.to(device)
# Out:
# WanTransformer3DModel(
#   (rope): WanRotaryPosEmbed()
#   (patch_embedding): Conv3d(48, 3072, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#   (condition_embedder): WanTimeTextImageEmbedding(
#     (timesteps_proj): Timesteps()
#     (time_embedder): TimestepEmbedding(
#       (linear_1): Linear(in_features=256, out_features=3072, bias=True)
#       (act): SiLU()
#       (linear_2): Linear(in_features=3072, out_features=3072, bias=True)
#     )
#     (act_fn): SiLU()
#     (time_proj): Linear(in_features=3072, out_features=18432, bias=True)
#     (text_embedder): PixArtAlphaTextProjection(
#       (linear_1): Linear(in_features=4096, out_features=3072, bias=True)
#       (act_1): GELU(approximate='tanh')
#       (linear_2): Linear(in_features=3072, out_features=3072, bias=True)
#     )
#   )
#   (blocks): ModuleList(
#     (0-29): 30 x WanTransformerBlock(
#       (norm1): FP32LayerNorm((3072,), eps=1e-06, elementwise_affine=False)
#       (attn1): WanAttention(
#         (to_q): Linear(in_features=3072, out_features=3072, bias=True)
#         (to_k): Linear(in_features=3072, out_features=3072, bias=True)
#         (to_v): Linear(in_features=3072, out_features=3072, bias=True)
#         (to_out): ModuleList(
#           (0): Linear(in_features=3072, out_features=3072, bias=True)
#           (1): Dropout(p=0.0, inplace=False)
#         )
#         (norm_q): RMSNorm((3072,), eps=1e-06, elementwise_affine=True)
#         (norm_k): RMSNorm((3072,), eps=1e-06, elementwise_affine=True)
#       )
#       (attn2): WanAttention(
#         (to_q): Linear(in_features=3072, out_features=3072, bias=True)
#         (to_k): Linear(in_features=3072, out_features=3072, bias=True)
#         (to_v): Linear(in_features=3072, out_features=3072, bias=True)
#         (to_out): ModuleList(
#           (0): Linear(in_features=3072, out_features=3072, bias=True)
#           (1): Dropout(p=0.0, inplace=False)
#         )
#         (norm_q): RMSNorm((3072,), eps=1e-06, elementwise_affine=True)
#         (norm_k): RMSNorm((3072,), eps=1e-06, elementwise_affine=True)
#       )
#       (norm2): FP32LayerNorm((3072,), eps=1e-06, elementwise_affine=True)
#       (ffn): FeedForward(
#         (net): ModuleList(
#           (0): GELU(
#             (proj): Linear(in_features=3072, out_features=14336, bias=True)
#           )
#           (1): Dropout(p=0.0, inplace=False)
#           (2): Linear(in_features=14336, out_features=3072, bias=True)
#         )
#       )
#       (norm3): FP32LayerNorm((3072,), eps=1e-06, elementwise_affine=False)
#     )
#   )
#   (norm_out): FP32LayerNorm((3072,), eps=1e-06, elementwise_affine=False)
#   (proj_out): Linear(in_features=3072, out_features=192, bias=True)
# )

# %%
pipe.vae.config.keys()
# Out:
# odict_keys(['base_dim', 'decoder_base_dim', 'z_dim', 'dim_mult', 'num_res_blocks', 'attn_scales', 'temperal_downsample', 'dropout', 'latents_mean', 'latents_std', 'is_residual', 'in_channels', 'out_channels', 'patch_size', 'scale_factor_temporal', 'scale_factor_spatial', '_class_name', '_diffusers_version', 'clip_output', '_name_or_path'])

# %%
from peft import LoraConfig, get_peft_model

# ── Step 1: Inspect the transformer to find exact module names ────────────────
transformer = pipe.transformer

# Print all linear layer names in the model
for name, module in transformer.named_modules():
    if isinstance(module, torch.nn.Linear):
        print(name)
# Out:
# condition_embedder.time_embedder.linear_1
# condition_embedder.time_embedder.linear_2
# condition_embedder.time_proj
# condition_embedder.text_embedder.linear_1
# condition_embedder.text_embedder.linear_2
# blocks.0.attn1.to_q
# blocks.0.attn1.to_k
# blocks.0.attn1.to_v
# blocks.0.attn1.to_out.0
# blocks.0.attn2.to_q
# blocks.0.attn2.to_k
# blocks.0.attn2.to_v
# blocks.0.attn2.to_out.0
# blocks.0.ffn.net.0.proj
# blocks.0.ffn.net.2
# blocks.1.attn1.to_q
# blocks.1.attn1.to_k
# blocks.1.attn1.to_v
# blocks.1.attn1.to_out.0
# blocks.1.attn2.to_q
# blocks.1.attn2.to_k
# blocks.1.attn2.to_v
# blocks.1.attn2.to_out.0
# blocks.1.ffn.net.0.proj
# blocks.1.ffn.net.2
# blocks.2.attn1.to_q
# blocks.2.attn1.to_k
# blocks.2.attn1.to_v
# blocks.2.attn1.to_out.0
# blocks.2.attn2.to_q
# blocks.2.attn2.to_k
# blocks.2.attn2.to_v
# blocks.2.attn2.to_out.0
# blocks.2.ffn.net.0.proj
# blocks.2.ffn.net.2
# blocks.3.attn1.to_q
# blocks.3.attn1.to_k
# blocks.3.attn1.to_v
# blocks.3.attn1.to_out.0
# blocks.3.attn2.to_q
# blocks.3.attn2.to_k
# blocks.3.attn2.to_v
# blocks.3.attn2.to_out.0
# blocks.3.ffn.net.0.proj
# blocks.3.ffn.net.2
# blocks.4.attn1.to_q
# blocks.4.attn1.to_k
# blocks.4.attn1.to_v
# blocks.4.attn1.to_out.0
# blocks.4.attn2.to_q
# blocks.4.attn2.to_k
# blocks.4.attn2.to_v
# blocks.4.attn2.to_out.0
# blocks.4.ffn.net.0.proj
# blocks.4.ffn.net.2
# blocks.5.attn1.to_q
# blocks.5.attn1.to_k
# blocks.5.attn1.to_v
# blocks.5.attn1.to_out.0
# blocks.5.attn2.to_q
# blocks.5.attn2.to_k
# blocks.5.attn2.to_v
# blocks.5.attn2.to_out.0
# blocks.5.ffn.net.0.proj
# blocks.5.ffn.net.2
# blocks.6.attn1.to_q
# blocks.6.attn1.to_k
# blocks.6.attn1.to_v
# blocks.6.attn1.to_out.0
# blocks.6.attn2.to_q
# blocks.6.attn2.to_k
# blocks.6.attn2.to_v
# blocks.6.attn2.to_out.0
# blocks.6.ffn.net.0.proj
# blocks.6.ffn.net.2
# blocks.7.attn1.to_q
# blocks.7.attn1.to_k
# blocks.7.attn1.to_v
# blocks.7.attn1.to_out.0
# blocks.7.attn2.to_q
# blocks.7.attn2.to_k
# blocks.7.attn2.to_v
# blocks.7.attn2.to_out.0
# blocks.7.ffn.net.0.proj
# blocks.7.ffn.net.2
# blocks.8.attn1.to_q
# blocks.8.attn1.to_k
# blocks.8.attn1.to_v
# blocks.8.attn1.to_out.0
# blocks.8.attn2.to_q
# blocks.8.attn2.to_k
# blocks.8.attn2.to_v
# blocks.8.attn2.to_out.0
# blocks.8.ffn.net.0.proj
# blocks.8.ffn.net.2
# blocks.9.attn1.to_q
# blocks.9.attn1.to_k
# blocks.9.attn1.to_v
# blocks.9.attn1.to_out.0
# blocks.9.attn2.to_q
# blocks.9.attn2.to_k
# blocks.9.attn2.to_v
# blocks.9.attn2.to_out.0
# blocks.9.ffn.net.0.proj
# blocks.9.ffn.net.2
# blocks.10.attn1.to_q
# blocks.10.attn1.to_k
# blocks.10.attn1.to_v
# blocks.10.attn1.to_out.0
# blocks.10.attn2.to_q
# blocks.10.attn2.to_k
# blocks.10.attn2.to_v
# blocks.10.attn2.to_out.0
# blocks.10.ffn.net.0.proj
# blocks.10.ffn.net.2
# blocks.11.attn1.to_q
# blocks.11.attn1.to_k
# blocks.11.attn1.to_v
# blocks.11.attn1.to_out.0
# blocks.11.attn2.to_q
# blocks.11.attn2.to_k
# blocks.11.attn2.to_v
# blocks.11.attn2.to_out.0
# blocks.11.ffn.net.0.proj
# blocks.11.ffn.net.2
# blocks.12.attn1.to_q
# blocks.12.attn1.to_k
# blocks.12.attn1.to_v
# blocks.12.attn1.to_out.0
# blocks.12.attn2.to_q
# blocks.12.attn2.to_k
# blocks.12.attn2.to_v
# blocks.12.attn2.to_out.0
# blocks.12.ffn.net.0.proj
# blocks.12.ffn.net.2
# blocks.13.attn1.to_q
# blocks.13.attn1.to_k
# blocks.13.attn1.to_v
# blocks.13.attn1.to_out.0
# blocks.13.attn2.to_q
# blocks.13.attn2.to_k
# blocks.13.attn2.to_v
# blocks.13.attn2.to_out.0
# blocks.13.ffn.net.0.proj
# blocks.13.ffn.net.2
# blocks.14.attn1.to_q
# blocks.14.attn1.to_k
# blocks.14.attn1.to_v
# blocks.14.attn1.to_out.0
# blocks.14.attn2.to_q
# blocks.14.attn2.to_k
# blocks.14.attn2.to_v
# blocks.14.attn2.to_out.0
# blocks.14.ffn.net.0.proj
# blocks.14.ffn.net.2
# blocks.15.attn1.to_q
# blocks.15.attn1.to_k
# blocks.15.attn1.to_v
# blocks.15.attn1.to_out.0
# blocks.15.attn2.to_q
# blocks.15.attn2.to_k
# blocks.15.attn2.to_v
# blocks.15.attn2.to_out.0
# blocks.15.ffn.net.0.proj
# blocks.15.ffn.net.2
# blocks.16.attn1.to_q
# blocks.16.attn1.to_k
# blocks.16.attn1.to_v
# blocks.16.attn1.to_out.0
# blocks.16.attn2.to_q
# blocks.16.attn2.to_k
# blocks.16.attn2.to_v
# blocks.16.attn2.to_out.0
# blocks.16.ffn.net.0.proj
# blocks.16.ffn.net.2
# blocks.17.attn1.to_q
# blocks.17.attn1.to_k
# blocks.17.attn1.to_v
# blocks.17.attn1.to_out.0
# blocks.17.attn2.to_q
# blocks.17.attn2.to_k
# blocks.17.attn2.to_v
# blocks.17.attn2.to_out.0
# blocks.17.ffn.net.0.proj
# blocks.17.ffn.net.2
# blocks.18.attn1.to_q
# blocks.18.attn1.to_k
# blocks.18.attn1.to_v
# blocks.18.attn1.to_out.0
# blocks.18.attn2.to_q
# blocks.18.attn2.to_k
# blocks.18.attn2.to_v
# blocks.18.attn2.to_out.0
# blocks.18.ffn.net.0.proj
# blocks.18.ffn.net.2
# blocks.19.attn1.to_q
# blocks.19.attn1.to_k
# blocks.19.attn1.to_v
# blocks.19.attn1.to_out.0
# blocks.19.attn2.to_q
# blocks.19.attn2.to_k
# blocks.19.attn2.to_v
# blocks.19.attn2.to_out.0
# blocks.19.ffn.net.0.proj
# blocks.19.ffn.net.2
# blocks.20.attn1.to_q
# blocks.20.attn1.to_k
# blocks.20.attn1.to_v
# blocks.20.attn1.to_out.0
# blocks.20.attn2.to_q
# blocks.20.attn2.to_k
# blocks.20.attn2.to_v
# blocks.20.attn2.to_out.0
# blocks.20.ffn.net.0.proj
# blocks.20.ffn.net.2
# blocks.21.attn1.to_q
# blocks.21.attn1.to_k
# blocks.21.attn1.to_v
# blocks.21.attn1.to_out.0
# blocks.21.attn2.to_q
# blocks.21.attn2.to_k
# blocks.21.attn2.to_v
# blocks.21.attn2.to_out.0
# blocks.21.ffn.net.0.proj
# blocks.21.ffn.net.2
# blocks.22.attn1.to_q
# blocks.22.attn1.to_k
# blocks.22.attn1.to_v
# blocks.22.attn1.to_out.0
# blocks.22.attn2.to_q
# blocks.22.attn2.to_k
# blocks.22.attn2.to_v
# blocks.22.attn2.to_out.0
# blocks.22.ffn.net.0.proj
# blocks.22.ffn.net.2
# blocks.23.attn1.to_q
# blocks.23.attn1.to_k
# blocks.23.attn1.to_v
# blocks.23.attn1.to_out.0
# blocks.23.attn2.to_q
# blocks.23.attn2.to_k
# blocks.23.attn2.to_v
# blocks.23.attn2.to_out.0
# blocks.23.ffn.net.0.proj
# blocks.23.ffn.net.2
# blocks.24.attn1.to_q
# blocks.24.attn1.to_k
# blocks.24.attn1.to_v
# blocks.24.attn1.to_out.0
# blocks.24.attn2.to_q
# blocks.24.attn2.to_k
# blocks.24.attn2.to_v
# blocks.24.attn2.to_out.0
# blocks.24.ffn.net.0.proj
# blocks.24.ffn.net.2
# blocks.25.attn1.to_q
# blocks.25.attn1.to_k
# blocks.25.attn1.to_v
# blocks.25.attn1.to_out.0
# blocks.25.attn2.to_q
# blocks.25.attn2.to_k
# blocks.25.attn2.to_v
# blocks.25.attn2.to_out.0
# blocks.25.ffn.net.0.proj
# blocks.25.ffn.net.2
# blocks.26.attn1.to_q
# blocks.26.attn1.to_k
# blocks.26.attn1.to_v
# blocks.26.attn1.to_out.0
# blocks.26.attn2.to_q
# blocks.26.attn2.to_k
# blocks.26.attn2.to_v
# blocks.26.attn2.to_out.0
# blocks.26.ffn.net.0.proj
# blocks.26.ffn.net.2
# blocks.27.attn1.to_q
# blocks.27.attn1.to_k
# blocks.27.attn1.to_v
# blocks.27.attn1.to_out.0
# blocks.27.attn2.to_q
# blocks.27.attn2.to_k
# blocks.27.attn2.to_v
# blocks.27.attn2.to_out.0
# blocks.27.ffn.net.0.proj
# blocks.27.ffn.net.2
# blocks.28.attn1.to_q
# blocks.28.attn1.to_k
# blocks.28.attn1.to_v
# blocks.28.attn1.to_out.0
# blocks.28.attn2.to_q
# blocks.28.attn2.to_k
# blocks.28.attn2.to_v
# blocks.28.attn2.to_out.0
# blocks.28.ffn.net.0.proj
# blocks.28.ffn.net.2
# blocks.29.attn1.to_q
# blocks.29.attn1.to_k
# blocks.29.attn1.to_v
# blocks.29.attn1.to_out.0
# blocks.29.attn2.to_q
# blocks.29.attn2.to_k
# blocks.29.attn2.to_v
# blocks.29.attn2.to_out.0
# blocks.29.ffn.net.0.proj
# blocks.29.ffn.net.2
# proj_out

# %%
# Apply LoRA
# ── Step 2: Apply LoRA to the transformer ────────────────────────────────────
lora_config = LoraConfig(
    r=16,
    lora_alpha=16,
    # Use suffixes — PEFT will match any layer whose name ends with these
    target_modules=["to_q", "to_k", "to_v", "to_out.0"],  # attention only (cheaper)
    # target_modules="all-linear",                          # everything (more expressive)
    lora_dropout=0.0,
    bias="none",
)

# transformer = get_peft_model(transformer, lora_config)

# transformer.print_trainable_parameters()
# # e.g. trainable params: 12,000,000 || all params: 5,100,000,000 || trainable%: 0.24%

# # Plug it back into the pipe
# pipe.transformer = transformer
from peft import PeftModel

final_model_checkpoint_path = "/content/drive/MyDrive/CS234_Project/checkpoints/wan_ddpo_2.5e-4_batch_16_epoch0"
pipe.transformer = PeftModel.from_pretrained(
    transformer,  # base transformer, not already wrapped
    final_model_checkpoint_path
)
pipe.transformer.print_trainable_parameters()
# Out:
# /usr/local/lib/python3.12/dist-packages/peft/tuners/tuners_utils.py:285: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(
# trainable params: 0 || all params: 5,023,380,672 || trainable%: 0.0000

# %%
pipe.transformer.enable_adapter_layers()
# for name, param in pipe.transformer.named_parameters():
#     if 'lora' in name:
#         param.requires_grad_(True)

# pipe.transformer.print_trainable_parameters()

# %%
# ── Step 3: Training setup ────────────────────────────────────────────────────
# optimizer = torch.optim.AdamW(
#     filter(lambda p: p.requires_grad, transformer.parameters()),
#     lr=1e-4,
# )

# Keep vae + text_encoder frozen
pipe.vae.requires_grad_(False)
pipe.text_encoder.requires_grad_(False)
# Out:
# UMT5EncoderModel(
#   (shared): Embedding(256384, 4096)
#   (encoder): UMT5Stack(
#     (embed_tokens): Embedding(256384, 4096)
#     (block): ModuleList(
#       (0-23): 24 x UMT5Block(
#         (layer): ModuleList(
#           (0): UMT5LayerSelfAttention(
#             (SelfAttention): UMT5Attention(
#               (q): Linear(in_features=4096, out_features=4096, bias=False)
#               (k): Linear(in_features=4096, out_features=4096, bias=False)
#               (v): Linear(in_features=4096, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=4096, bias=False)
#               (relative_attention_bias): Embedding(32, 64)
#             )
#             (layer_norm): UMT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): UMT5LayerFF(
#             (DenseReluDense): UMT5DenseGatedActDense(
#               (wi_0): Linear(in_features=4096, out_features=10240, bias=False)
#               (wi_1): Linear(in_features=4096, out_features=10240, bias=False)
#               (wo): Linear(in_features=10240, out_features=4096, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): UMT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): UMT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
#cbaaaa

# %%
pipe.transformer.enable_adapter_layers()

# %%
dataloader = torch.utils.data.DataLoader(test_prompts, batch_size=1, shuffle=False)

# %%
import torch
import numpy as np
import gc
import os
from diffusers import WanPipeline, AutoencoderKLWan
from diffusers.utils import export_to_video

# ── Config ────────────────────────────────────────────────────────────────────
dtype = torch.bfloat16
device = "cuda"
model_id = "Wan-AI/Wan2.2-TI2V-5B-Diffusers"

HEIGHT = 704
WIDTH = 1280
NUM_FRAMES = 81
NUM_INFERENCE_STEPS = 50
GUIDANCE_SCALE = 3.5
FPS = 16
OUTPUT_DIR = "/content/drive/MyDrive/CS234_Project/eval_vids/"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ── Model loading ─────────────────────────────────────────────────────────────
# vae = AutoencoderKLWan.from_pretrained(model_id, subfolder="vae", torch_dtype=torch.float32)
# pipe = WanPipeline.from_pretrained(model_id, vae=vae, torch_dtype=dtype)
pipe.enable_model_cpu_offload()
pipe.vae.enable_tiling()
pipe.vae.enable_slicing()

results = []

for i, batch in enumerate(dataloader):
    prompts = batch
    video_paths = []

    with torch.no_grad():
        for j, prompt in enumerate(prompts):
            torch.cuda.empty_cache()
            frames = pipe(
                prompt=prompt,
                height=HEIGHT,
                width=WIDTH,
                num_frames=NUM_FRAMES,
                guidance_scale=GUIDANCE_SCALE,
                num_inference_steps=NUM_INFERENCE_STEPS,
            ).frames[0]

            video_path = os.path.join(OUTPUT_DIR, f"{i:04d}_{j:02d}.mp4")
            export_to_video(frames, video_path, fps=FPS)
            video_paths.append(video_path)
            del frames
            torch.cuda.empty_cache()
            gc.collect()

    torch.cuda.empty_cache()
    gc.collect()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
